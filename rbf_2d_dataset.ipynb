# %% [markdown]
# <a href="https://colab.research.google.com/github/tranbaquang1708/GraduationThesis/blob/develop/rbf_2d_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Method: RBF
# Data set: 2D
#----------------------------------------------

# %%
import sys
import os
mp = os.path.abspath(os.path.join('/content/drive/My Drive/GraduationThesis/gitrepo/GraduationThesis/'))
sys.path.append(mp)

# %%
import numpy as np
import timeit
from modules import Rbf

# %%
# Create dataset
# Import point data
filename = mp + "/dataset/2d/superior.vert"
dataset,normal_vectors = Rbf.gen_from_txt2(filename, offset=0.01)

# %%
#Solve weight function
w = Rbf.solve_w_func(dataset, offset=0.01, func=Rbf.thin_plate)

# %%
# Evaluate f(x,y) on a 2D regular grid obtained from meshgrid
xx,yy = Rbf.grid(dataset[:,0], dataset[:,1])
z = Rbf.sampling(dataset, w, xx, yy, func=Rbf.thin_plate)

# %%
# Visualize
Rbf.visualize2(dataset, normal_vectors, xx, yy, z)
